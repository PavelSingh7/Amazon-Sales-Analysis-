# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
amazon = pd.read_csv("C:\\Users\\pavel\\OneDrive\\Desktop\Sem 4\\Capstone Project 2\\Amazon Sale Report.csv")
# Out:
# C:\Users\pavel\AppData\Local\Temp\ipykernel_372\3404743497.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   amazon = pd.read_csv("C:\\Users\\pavel\\OneDrive\\Desktop\Sem 4\\Capstone Project 2\\Amazon Sale Report.csv")

# %%
amazon.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
import missingno as msno

# %%
amazon.set_index('index', inplace = True)

# %% [markdown]
# ### checking null values

# %%
msno.matrix(amazon)
# Out:
# <AxesSubplot:>

# %%
msno.bar(amazon)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Checking unique values

# %%
amazon.nunique()
# Out:
# Order ID              120378
# Date                      91
# Status                    13
# Fulfilment                 2
# Sales Channel              2
# ship-service-level         2
# Style                   1377
# SKU                     7195
# Category                   9
# Size                      11
# ASIN                    7190
# Courier Status             3
# Qty                       10
# currency                   1
# Amount                  1410
# ship-city               8955
# ship-state                69
# ship-postal-code        9459
# ship-country               1
# promotion-ids           5787
# B2B                        2
# fulfilled-by               1
# Unnamed: 22                1
# dtype: int64

# %%
amazon.apply(pd.unique)
# Out:
# Order ID              [405-8078784-5731545, 171-9198151-1101146, 404...
# Date                  [04-30-22, 04-29-22, 04-28-22, 04-27-22, 04-26...
# Status                [Cancelled, Shipped - Delivered to Buyer, Ship...
# Fulfilment                                           [Merchant, Amazon]
# Sales Channel                                   [Amazon.in, Non-Amazon]
# ship-service-level                                [Standard, Expedited]
# Style                 [SET389, JNE3781, JNE3371, J0341, JNE3671, SET...
# SKU                   [SET389-KR-NP-S, JNE3781-KR-XXXL, JNE3371-KR-X...
# Category              [Set, kurta, Western Dress, Top, Ethnic Dress,...
# Size                   [S, 3XL, XL, L, XXL, XS, 6XL, M, 4XL, 5XL, Free]
# ASIN                  [B09KXVBD7Z, B09K3WFS32, B07WV4JV4D, B099NRCT7...
# Courier Status                     [nan, Shipped, Cancelled, Unshipped]
# Qty                                    [0, 1, 2, 15, 3, 9, 13, 5, 4, 8]
# ...

# %% [markdown]
# ## Dropping unnecessary Columns

# %%
amazon.drop(columns = ['Unnamed: 22','fulfilled-by','ship-country', 'currency',], inplace = True)

# %%
amazon=amazon[amazon['Sales Channel ']=='Amazon.in']

# %% [markdown]
# ## Checking and removing duplicate rows

# %%
before_remove_duplicates = len(amazon)

# %%
amazon.drop_duplicates(inplace = True)
after_remove_duplicates = len(amazon)
duplicate_rows_removed = before_remove_duplicates - after_remove_duplicates
print(f'{duplicate_rows_removed} duplicate rows have been removed! \nThe Dataset now has {after_remove_duplicates} rows.')
# Out:
# 6 duplicate rows have been removed!
# The Dataset now has 128845 rows.

# %%
amazon[amazon.isnull().any(axis = 1)]
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# index
# 0       405-8078784-5731545  04-30-22  Cancelled   Merchant      Amazon.in
# 3       403-9615377-8133951  04-30-22  Cancelled   Merchant      Amazon.in
# 4       407-1069790-7240320  04-30-22    Shipped     Amazon      Amazon.in
# 8       407-5443024-5233168  04-30-22  Cancelled     Amazon      Amazon.in
# 9       402-4393761-0311520  04-30-22    Shipped     Amazon      Amazon.in
# ...                     ...       ...        ...        ...            ...
# 128966  406-9812666-2474761  05-31-22    Shipped     Amazon      Amazon.in
# 128967  404-5182288-1653947  05-31-22  Cancelled     Amazon      Amazon.in
# 128969  404-3802633-7250760  05-31-22  Cancelled     Amazon      Amazon.in
# 128970  406-6001380-7673107  05-31-22    Shipped     Amazon      Amazon.in
# 128972  407-9547469-3152358  05-31-22    Shipped     Amazon      Amazon.in
#
# ...

# %%
amazon[amazon['promotion-ids'].isnull()]
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# index
# 0       405-8078784-5731545  04-30-22  Cancelled   Merchant      Amazon.in
# 3       403-9615377-8133951  04-30-22  Cancelled   Merchant      Amazon.in
# 4       407-1069790-7240320  04-30-22    Shipped     Amazon      Amazon.in
# 9       402-4393761-0311520  04-30-22    Shipped     Amazon      Amazon.in
# 10      407-5633625-6970741  04-30-22    Shipped     Amazon      Amazon.in
# ...                     ...       ...        ...        ...            ...
# 128966  406-9812666-2474761  05-31-22    Shipped     Amazon      Amazon.in
# 128967  404-5182288-1653947  05-31-22  Cancelled     Amazon      Amazon.in
# 128969  404-3802633-7250760  05-31-22  Cancelled     Amazon      Amazon.in
# 128970  406-6001380-7673107  05-31-22    Shipped     Amazon      Amazon.in
# 128972  407-9547469-3152358  05-31-22    Shipped     Amazon      Amazon.in
#
# ...

# %% [markdown]
# ## Handling Missing Values in different Columns according to the need

# %%
amazon['promotion-ids'].fillna('no promotion', inplace = True)

# %%
amazon['Courier Status'].fillna('unknown', inplace = True)

# %%
amazon[amazon['Amount'].isnull()]
# Out:
#                    Order ID      Date     Status Fulfilment Sales Channel   \
# index
# 8       407-5443024-5233168  04-30-22  Cancelled     Amazon      Amazon.in
# 29      404-5933402-8801952  04-30-22  Cancelled   Merchant      Amazon.in
# 65      171-4137548-0481151  04-30-22  Cancelled     Amazon      Amazon.in
# 84      403-9950518-0349133  04-30-22  Cancelled     Amazon      Amazon.in
# 95      405-9112089-3379536  04-30-22  Cancelled     Amazon      Amazon.in
# ...                     ...       ...        ...        ...            ...
# 128903  406-3923120-4345139  05-31-22  Cancelled     Amazon      Amazon.in
# 128907  403-6757403-6097100  05-31-22  Cancelled     Amazon      Amazon.in
# 128908  403-6757403-6097100  05-31-22  Cancelled     Amazon      Amazon.in
# 128958  408-9513596-4393945  05-31-22  Cancelled     Amazon      Amazon.in
# 128967  404-5182288-1653947  05-31-22  Cancelled     Amazon      Amazon.in
#
# ...

# %%
amazon['Amount'].fillna(0, inplace = True)

# %%
msno.matrix(amazon)
# Out:
# <AxesSubplot:>

# %%
amazon[amazon['ship-city'].isnull()]
# Out:
#                    Order ID      Date                        Status  \
# index
# 1871    404-0566904-4825137  04-29-22                       Shipped
# 1872    404-0566904-4825137  04-29-22                       Shipped
# 8752    406-4003386-8768363  04-25-22                       Shipped
# 11215   402-0107720-7057168  04-23-22                       Shipped
# 13252   407-4532637-8415521  04-22-22                     Cancelled
# 15688   404-9229894-8608305  04-21-22                       Shipped
# 16787   402-4919636-4333150  04-20-22  Shipped - Delivered to Buyer
# 18351   405-4927647-8064368  04-19-22                       Shipped
# 22930   402-8628677-0457954  04-16-22  Shipped - Returned to Seller
# 24986   406-4079063-8291520  04-15-22                     Cancelled
# 30379   404-7506843-7913132  04-12-22  Shipped - Delivered to Buyer
# 37963   407-3064376-9158743  04-08-22                     Cancelled
# 37964   407-3064376-9158743  04-08-22                     Cancelled
# ...

# %%
amazon['ship-city'].fillna('unknown', inplace = True)
amazon['ship-state'].fillna('unknown', inplace = True)
amazon['ship-postal-code'].fillna('unknown', inplace = True)

# %%
msno.bar(amazon)
# Out:
# <AxesSubplot:>

# %%
amazon.dtypes
# Out:
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code       object
# promotion-ids          object
# B2B                      bool
# dtype: object

# %% [markdown]
# ## Handling datatype for Date Column

# %%
amazon['Date'] = pd.to_datetime(amazon['Date'])

# %% [markdown]
# ## Renaming all the columns

# %%
mapper = {'Order ID':'orderID', 'Date':'date', 'Status':'shipStatus','Fullfilment':'fullfilment','Sales Channel':'sales_channel', 'ship-service-level':'serviceLevel', 'Style':'style', 'SKU':'sku', 'Category':'productCategory', 'Size':'size', 'ASIN':'asin', 'Courier Status':'courierShipStatus', 'Qty':'orderQuantity', 'Amount':'orderAmount (INR)', 'ship-city':'city', 'ship-state':'state', 'ship-postal-code':'zip', 'promotion-ids':'promotion','B2B':'customerType' }
amazon.rename(columns = mapper, inplace = True)
amazon.head()
# Out:
#                    orderID       date                    shipStatus  \
# index
# 0      405-8078784-5731545 2022-04-30                     Cancelled
# 1      171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      404-0687676-7273146 2022-04-30                       Shipped
# 3      403-9615377-8133951 2022-04-30                     Cancelled
# 4      407-1069790-7240320 2022-04-30                       Shipped
#
#       Fulfilment Sales Channel  serviceLevel    style              sku  \
# index
# 0       Merchant      Amazon.in     Standard   SET389   SET389-KR-NP-S
# 1       Merchant      Amazon.in     Standard  JNE3781  JNE3781-KR-XXXL
# 2         Amazon      Amazon.in    Expedited  JNE3371    JNE3371-KR-XL
# 3       Merchant      Amazon.in     Standard    J0341       J0341-DR-L
# 4         Amazon      Amazon.in    Expedited  JNE3671  JNE3671-TU-XXXL
#
#       productCategory size        asin courierShipStatus  orderQuantity  \
# index
# ...

# %% [markdown]
# ## Handling CustomerType Column

# %%
amazon['customerType'].replace([True, False], ['business', 'consumer'], inplace = True)
amazon.head()
# Out:
#                    orderID       date                    shipStatus  \
# index
# 0      405-8078784-5731545 2022-04-30                     Cancelled
# 1      171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      404-0687676-7273146 2022-04-30                       Shipped
# 3      403-9615377-8133951 2022-04-30                     Cancelled
# 4      407-1069790-7240320 2022-04-30                       Shipped
#
#       Fulfilment Sales Channel  serviceLevel    style              sku  \
# index
# 0       Merchant      Amazon.in     Standard   SET389   SET389-KR-NP-S
# 1       Merchant      Amazon.in     Standard  JNE3781  JNE3781-KR-XXXL
# 2         Amazon      Amazon.in    Expedited  JNE3371    JNE3371-KR-XL
# 3       Merchant      Amazon.in     Standard    J0341       J0341-DR-L
# 4         Amazon      Amazon.in    Expedited  JNE3671  JNE3671-TU-XXXL
#
#       productCategory size        asin courierShipStatus  orderQuantity  \
# index
# ...

# %% [markdown]
# ## Dataset is fully cleaned and is ready to be used for Visulizations in Tableau and for training the Machine Learning Model.
